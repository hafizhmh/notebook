# %%
# Hafizh Mulya H.-18117030, Muhammad Athallah Rizki Putra-18117002, & Muhammad Hanif Naufal Eka Wiratama-18117027
# Update: 20 Agustus 2021
# Tugas Mata Kuliah ET4047 Inteligensi Buatan
# Depression Detection pada tweet
# Juga tersedia di https://colab.research.google.com/drive/1c5Ix4HA1q7BjnR6hBdrHEhge0I8a1EGI?usp=sharing

# %% [markdown]
# Detecting depression in Tweets using TF - IDF

# %% [markdown]
# Installing and importing libraries

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from math import log, sqrt
import pandas as pd
import numpy as np
import re
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
url = 'https://raw.githubusercontent.com/RizkiPutra660/Depression-Tweets-Detection/main/Depression%20Sentiment%20Tweets.csv'
tweets = pd.read_csv(url, error_bad_lines=False)
tweets.drop(['Unnamed: 0'], axis = 1, inplace = True)
tweets.head()
# Out:
#                                              message  label
# 0  just had a real good moment. i missssssssss hi...      0
# 1         is reading manga  http://plurk.com/p/mzp1e      0
# 2  @comeagainjen http://twitpic.com/2y2lx - http:...      0
# 3  @lapcat Need to send 'em to my accountant tomo...      0
# 4      ADD ME ON MYSPACE!!!  myspace.com/LookThunder      0

# %%
tweets['label'].value_counts()
# Out:
# 0    8000
# 1    2314
# Name: label, dtype: int64

# %% [markdown]
# Splitting the Data in Training and Testing Sets

# %%
totalTweets = 8000 + 2314
trainIndex, testIndex = list(), list()
for i in range(tweets.shape[0]):
    if np.random.uniform(0, 1) < 0.98:
        trainIndex += [i]
    else:
        testIndex += [i]
trainData = tweets.iloc[trainIndex]
testData = tweets.iloc[testIndex]

# %%
trainData['label'].value_counts()
# Out:
# 0    7845
# 1    2264
# Name: label, dtype: int64

# %%
trainData.head()
# Out:
#                                              message  label
# 0  just had a real good moment. i missssssssss hi...      0
# 1         is reading manga  http://plurk.com/p/mzp1e      0
# 2  @comeagainjen http://twitpic.com/2y2lx - http:...      0
# 3  @lapcat Need to send 'em to my accountant tomo...      0
# 4      ADD ME ON MYSPACE!!!  myspace.com/LookThunder      0

# %%
testData['label'].value_counts()
# Out:
# 0    155
# 1     50
# Name: label, dtype: int64

# %%
testData.head()
# Out:
#                                                message  label
# 73                                       Is in Athens       0
# 90   @kdurose yep, but we fought back well. think i...      0
# 135  Okay, have torn apart my work. Fresh coffee &a...      0
# 155  @KoldCastTV and @beautyboutique Thanks for fol...      0
# 156                                     @RealWorldMom       0

# %% [markdown]
# Pre-processing the data for the training: Tokenization, stopwords removal, and stemming. 2-gram is used.

# %%
def process_message(message, lower_case = True, stem = True, stop_words = True, gram = 2):
    if lower_case:
        message = message.lower()
    words = word_tokenize(message)
    words = [w for w in words if len(w) > 2]
    if stop_words:
        sw = stopwords.words('english')
        words = [word for word in words if word not in sw]
    if gram > 1:
        w = []
        for i in range(len(words) - gram + 1):
            w += [' '.join(words[i:i + gram])]
        return w
    if stem:
        stemmer = PorterStemmer()
        words = [stemmer.stem(word) for word in words]   
    return words

# %% [markdown]
# TF-IDF is used to reflect how important a word is to a document in a collection or corpus, in this case TF-IDF is used to reflect how important a word is to a tweet in a set of tweets.

# %%
class TweetClassifier(object):
    def __init__(self, trainData, method = 'tf-idf'):
        self.tweets, self.labels = trainData['message'], trainData['label']
        self.method = method

    def train(self):
        self.calc_TF_and_IDF()
        if self.method == 'tf-idf':
            self.calc_TF_IDF()
        else:
            self.calc_prob()

    def calc_prob(self):
        self.prob_depressive = dict()
        self.prob_positive = dict()
        for word in self.tf_depressive:
            self.prob_depressive[word] = (self.tf_depressive[word] + 1) / (self.depressive_words + \
                                                                len(list(self.tf_depressive.keys())))
        for word in self.tf_positive:
            self.prob_positive[word] = (self.tf_positive[word] + 1) / (self.positive_words + \
                                                                len(list(self.tf_positive.keys())))
        self.prob_depressive_tweet, self.prob_positive_tweet = self.depressive_tweets / self.total_tweets, self.positive_tweets / self.total_tweets 

    def calc_TF_and_IDF(self):
        noOfMessages = self.tweets.shape[0]
        self.depressive_tweets, self.positive_tweets = self.labels.value_counts()[1], self.labels.value_counts()[0]
        self.total_tweets = self.depressive_tweets + self.positive_tweets
        self.depressive_words = 0
        self.positive_words = 0
        self.tf_depressive = dict()
        self.tf_positive = dict()
        self.idf_depressive = dict()
        self.idf_positive = dict()
        for i in range(noOfMessages):
            message_processed = process_message(self.tweets.iloc[i])
            #print(message_processed)
            count = list() #To keep track of whether the word has occured in the message or not.
                           #For IDF
            for word in message_processed:
                if self.labels.iloc[i]:
                    self.tf_depressive[word] = self.tf_depressive.get(word, 0) + 1
                    self.depressive_words += 1
                else:
                    self.tf_positive[word] = self.tf_positive.get(word, 0) + 1
                    self.positive_words += 1
                if word not in count:
                    count += [word]
            for word in count:
                if self.labels.iloc[i]:
                    self.idf_depressive[word] = self.idf_depressive.get(word, 0) + 1
                else:
                    self.idf_positive[word] = self.idf_positive.get(word, 0) + 1


    def calc_TF_IDF(self):
        self.prob_depressive = dict()
        self.prob_positive = dict()
        self.sum_tf_idf_depressive = 0
        self.sum_tf_idf_positive = 0
        for word in self.tf_depressive:
            self.prob_depressive[word] = (self.tf_depressive[word]) * log((self.depressive_tweets + self.positive_tweets) \
                                                          / (self.idf_depressive[word] + self.idf_positive.get(word, 0)))
            self.sum_tf_idf_depressive += self.prob_depressive[word]
        for word in self.tf_depressive:
            self.prob_depressive[word] = (self.prob_depressive[word] + 1) / (self.sum_tf_idf_depressive + len(list(self.prob_depressive.keys())))
            
        for word in self.tf_positive:
            self.prob_positive[word] = (self.tf_positive[word]) * log((self.depressive_tweets + self.positive_tweets) \
                                                          / (self.idf_depressive.get(word, 0) + self.idf_positive[word]))
            self.sum_tf_idf_positive += self.prob_positive[word]
        for word in self.tf_positive:
            self.prob_positive[word] = (self.prob_positive[word] + 1) / (self.sum_tf_idf_positive + len(list(self.prob_positive.keys())))
            
    
        self.prob_depressive_tweet, self.prob_positive_tweet = self.depressive_tweets / self.total_tweets, self.positive_tweets / self.total_tweets

    def classify(self, processed_message):
        pDepressive, pPositive = 0, 0
        for word in processed_message:                
            if word in self.prob_depressive:
                pDepressive += log(self.prob_depressive[word])
            else:
                if self.method == 'tf-idf':
                    pDepressive -= log(self.sum_tf_idf_depressive + len(list(self.prob_depressive.keys())))
                else:
                    pDepressive -= log(self.depressive_words + len(list(self.prob_depressive.keys())))
            if word in self.prob_positive:
                pPositive += log(self.prob_positive[word])
            else:
                if self.method == 'tf-idf':
                    pPositive -= log(self.sum_tf_idf_positive + len(list(self.prob_positive.keys()))) 
                else:
                    pPositive -= log(self.positive_words + len(list(self.prob_positive.keys())))
            pDepressive += log(self.prob_depressive_tweet)
            pPositive += log(self.prob_positive_tweet)
        return pDepressive >= pPositive
    
    def predict(self, testData):
        result = dict()
        for (i, message) in enumerate(testData):
            processed_message = process_message(message)
            result[i] = int(self.classify(processed_message))
        return result

# %%
def metrics(labels, predictions):
    true_pos, true_neg, false_pos, false_neg = 0, 0, 0, 0
    for i in range(len(labels)):
        true_pos += int(labels.iloc[i] == 1 and predictions[i] == 1)
        true_neg += int(labels.iloc[i] == 0 and predictions[i] == 0)
        false_pos += int(labels.iloc[i] == 0 and predictions[i] == 1)
        false_neg += int(labels.iloc[i] == 1 and predictions[i] == 0)
    print('apaan teh tadi')
    print(true_pos, true_neg, false_pos, false_neg)
    precision = true_pos / (true_pos + false_pos)
    recall = true_pos / (true_pos + false_neg)
    Fscore = 2 * precision * recall / (precision + recall)
    accuracy = (true_pos + true_neg) / (true_pos + true_neg + false_pos + false_neg)

    print("Precision: ", precision)
    print("Recall: ", recall)
    print("F-score: ", Fscore)
    print("Accuracy: ", accuracy)

# %%
# Misal pakai metode selain tf-idf (baru tersedia kalkulasi probabilistik biasa)
sc_tf_idf = TweetClassifier(trainData, 'else')
sc_tf_idf.train()
preds_tf_idf = sc_tf_idf.predict(testData['message'])
metrics(testData['label'], preds_tf_idf)
# Out:
# apaan teh tadi
# 10 152 3 40
# Precision:  0.7692307692307693
# Recall:  0.2
# F-score:  0.31746031746031744
# Accuracy:  0.7902439024390244

# %%
# Misal pakai metode tf-idf
sc_tf_idf = TweetClassifier(trainData, 'tf-idf')
sc_tf_idf.train()
preds_tf_idf = sc_tf_idf.predict(testData['message'])
metrics(testData['label'], preds_tf_idf)
# Out:
# apaan teh tadi
# 22 152 3 28
# Precision:  0.88
# Recall:  0.44
# F-score:  0.5866666666666667
# Accuracy:  0.848780487804878

# %% [markdown]
# Predictions with TF-IDF

# %% [markdown]
# Depressive Tweets

# %%
pm = process_message('I\'m depressed')
sc_tf_idf.classify(pm)
# Out:
# True

# %%
pm = process_message('Depression are the worst')
sc_tf_idf.classify(pm)
# Out:
# True

# %%
pm = process_message('Lately I have been feeling unsure of myself as a person & an artist')
sc_tf_idf.classify(pm)
# Out:
# False

# %% [markdown]
# Non-Depressive Tweets

# %%
pm = process_message('Loving how me and my lovely partner is talking about what we want.')
sc_tf_idf.classify(pm)
# Out:
# False

# %%
pm = process_message('ICT Competition takes a lot of effort')
sc_tf_idf.classify(pm)
# Out:
# False

# %%
# 2-gram words yang memiliki label depressive, sort by value
x = sc_tf_idf.tf_depressive
{k: v for k, v in sorted(x.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'anxiety depression': 136,
#  'depression anxiety': 136,
#  'depression https': 86,
#  'mental health': 52,
#  "depression n't": 43,
#  'face emoji': 43,
#  'emoji face': 40,
#  'crying face': 40,
#  'depression emoji': 37,
#  'depression http': 36,
#  'emoji loudly': 33,
#  'loudly crying': 33,
#  'mom depression': 33,
#  'emoji heavy': 31,
#  'smiling face': 31,
#  'depression tied': 31,
#  'tied kids': 31,
#  'kids emotional': 31,
#  'skin tone': 31,
#  'heavy red': 30,
#  'red heart': 30,
#  'great depression': 30,
#  'mental illness': 30,
#  'emotional intellectual': 30,
#  'intellectual development': 30,
#  'feel like': 27,
#  "n't know": 26,
#  'risk depression': 26,
#  'emoji smiling': 25,
#  'depression nap': 25,
#  'face tears': 24,
#  'tears joy': 24,
#  '... https': 24,
#  'cured depression': 22,
#  'depression real': 22,
#  'ë°\x95ë´\x84ì \x9cë°\x9cë\x82´ë²\x84ë': 22,
#  'heart emoji': 21,
#  'depression ...': 20,
#  '\x9cë°\x9cë\x82´ë²\x84ë ¤ë\x91\x90ì\x84¸ì\x9a\x94': 20,
#  'cure depression': 19,
#  'light skin': 19,
#  'severe depression': 18,
#  '... ...': 17,
#  'stress anxiety': 17,
#  'puff cannabis': 17,
#  'development https': 16,
#  'crippling depression': 15,
#  'help depression': 15,
#  'clinical depression': 14,
#  'stress depression': 14,
#  'struggle depression': 14,
#  'ease depression': 14,
#  'depression really': 13,
#  'suicidal thoughts': 13,
#  'deep depression': 13,
#  'development http': 13,
#  'children teens': 13,
#  'teens anxiety': 13,
#  'depression stress': 12,
#  'know depression': 12,
#  'emoji weary': 12,
#  'weary face': 12,
#  'like depression': 12,
#  'chronic depression': 12,
#  'depression mental': 12,
#  'â\x80¦ via': 12,
#  'cuts risk': 12,
#  "n't want": 11,
#  'depression sucks': 11,
#  'depression suicide': 11,
#  'https //ift.tt/2htvzceâ': 11,
#  'depression drug': 11,
#  'cold sweat': 11,
#  'suffering depression': 10,
#  'via youtube': 10,
#  'get depression': 10,
#  "n't think": 10,
#  'major depression': 10,
#  'developing depression': 10,
#  'depression naps': 10,
#  'emoji pensive': 10,
#  'pensive face': 10,
#  'fight depression': 10,
#  "could 'one": 10,
#  "'one puff": 10,
#  'depression like': 9,
#  'emoji person': 9,
#  '... depression': 9,
#  'smiling eyes': 9,
#  'seasonal depression': 9,
#  'depression hours': 9,
#  "n't even": 9,
#  'postpartum depression': 9,
#  'symptoms depression': 9,
#  'hand sign': 9,
#  'tone emoji': 9,
#  'exercising regularly': 9,
#  'regularly cuts': 9,
#  'depression study': 9,
#  '//news.sky.com/story/exercising-regularly-cuts-risk-of-depression-by-16-study-suggests-11346264â â\x80¦': 9,
#  "n't depression": 9,
#  'depression mentalhealth': 9,
#  'concert depression': 9,
#  'suffer depression': 9,
#  'face cold': 9,
#  'depression feel': 8,
#  'every time': 8,
#  'depression one': 8,
#  'person folded': 8,
#  'folded hands': 8,
#  'day depression': 8,
#  'bipolar disorder': 8,
#  'love depression': 8,
#  'take depression': 8,
#  'depression hit': 8,
#  'cause depression': 8,
#  'panic attacks': 8,
#  'struggling depression': 8,
#  "'ve got": 8,
#  'study suggests': 8,
#  'http //news.sky.com/story/exercising-regularly-cuts-risk-of-depression-by-16-study-suggests-11346264â': 8,
#  'emoji upside-down': 8,
#  'upside-down face': 8,
#  'mentalhealth depression': 8,
#  'talks depression': 8,
#  'post concert': 8,
#  'choicedepression choicedepression': 8,
#  'eyes emoji': 8,
#  'depression ptsd': 8,
#  'sweat emoji': 8,
#  'one puff': 8,
#  'joy emoji': 8,
#  'depression cured': 7,
#  'depression get': 7,
#  'cures depression': 7,
#  'depression people': 7,
#  'depression bipolar': 7,
#  'fighting depression': 7,
#  'need help': 7,
#  'depression away': 7,
#  'depression always': 7,
#  'much depression': 7,
#  'signs depression': 7,
#  'depression suicidal': 7,
#  'emoji slightly': 7,
#  'depression hits': 7,
#  'emoji crying': 7,
#  'ist saddepression': 7,
#  'saddepression ist': 7,
#  'depression never': 7,
#  'depression right': 7,
#  'face https': 7,
#  'risk developing': 7,
#  'today depression': 7,
#  'open mouth': 7,
#  'talk depression': 7,
#  "n't take": 7,
#  'problems depression': 7,
#  'depression hitting': 7,
#  'emoji pointing': 7,
#  'face heart-shaped': 7,
#  'heart-shaped eyes': 7,
#  "people n't": 7,
#  'cannabis ease': 7,
#  'depression also': 7,
#  'drug addiction': 7,
#  'physical activity': 7,
#  'depression depression': 7,
#  'postnatal depression': 7,
#  "cannabis 'could": 7,
#  "'could ease": 7,
#  'https //www.sciencedaily.com/releases/2018/04/180424184119.htmâ': 7,
#  '//www.sciencedaily.com/releases/2018/04/180424184119.htmâ â\x80¦': 7,
#  'park bom': 7,
#  "n't get": 6,
#  'get better': 6,
#  'make feel': 6,
#  'face smiling': 6,
#  'depression coming': 6,
#  'away depression': 6,
#  'eating disorder': 6,
#  'self harm': 6,
#  'life new': 6,
#  'would like': 6,
#  'time depression': 6,
#  'prevent depression': 6,
#  'slightly smiling': 6,
#  'make sure': 6,
#  'emoji disappointed': 6,
#  'friends struggle': 6,
#  'depression app': 6,
#  'app helps': 6,
#  'helps avoid': 6,
#  'avoid potentially': 6,
#  'potentially harmful': 6,
#  'harmful phrases': 6,
#  'anxiety stress': 6,
#  'people depression': 6,
#  'emoji waving': 6,
#  'waving hand': 6,
#  'sign medium': 6,
#  'medium dark': 6,
#  'dark skin': 6,
#  'depression makes': 6,
#  'going depression': 6,
#  'someone else': 6,
#  'talking depression': 6,
#  'bipolar depression': 6,
#  'medium skin': 6,
#  'dealing depression': 6,
#  'depression take': 6,
#  'let depression': 6,
#  "n't give": 6,
#  'experience depression': 6,
#  'reason depression': 6,
#  'medium light': 6,
#  'suggests http': 6,
#  'https //www.youtube.com/watch': 6,
#  'â\x80¦ https': 6,
#  'twitter chat': 6,
#  'depression may': 6,
#  'hitting hard': 6,
#  "... n't": 6,
#  "addiction n't": 6,
#  'emoji two': 6,
#  'two hearts': 6,
#  'depression something': 5,
#  'emoji pouting': 5,
#  'pouting face': 5,
#  'deal depression': 5,
#  'mild depression': 5,
#  'depression even': 5,
#  'like know': 5,
#  'bipolar anxiety': 5,
#  'depression day': 5,
#  'depression way': 5,
#  'long time': 5,
#  'cherry blossom': 5,
#  'good day': 5,
#  'feel depression': 5,
#  'deeper depression': 5,
#  'social media': 5,
#  'good depression': 5,
#  'chance developing': 5,
#  'life https': 5,
#  'emoji cat': 5,
#  'cat face': 5,
#  "depression 've": 5,
#  'called depression': 5,
#  'depression many': 5,
#  'depression could': 5,
#  'depression glass': 5,
#  'depression time': 5,
#  'hello depression': 5,
#  'depression gone': 5,
#  'http //ow.ly/le9p30jf99gâ': 5,
#  'health issues': 5,
#  'thing depression': 5,
#  'years ago': 5,
#  'feel bad': 5,
#  'added video': 5,
#  'video youtube': 5,
#  'youtube playlist': 5,
#  'playlist http': 5,
#  'real depression': 5,
#  'someone depression': 5,
#  'depression fucking': 5,
#  'depression chronic': 5,
#  "n't let": 5,
#  'read http': 5,
#  'liked youtube': 5,
#  'youtube video': 5,
#  'video http': 5,
#  "could n't": 5,
#  'phrases http': 5,
#  'depression men': 5,
#  'illness depression': 5,
#  'depression good': 5,
#  'chemical imbalance': 5,
#  'battle depression': 5,
#  'study https': 5,
#  'depression feeling': 5,
#  'back depression': 5,
#  'feeling like': 5,
#  'low self-esteem': 5,
#  'rates depression': 5,
#  "n't mean": 5,
#  'suffered depression': 5,
#  'emoji woman': 5,
#  'new study': 5,
#  'wish could': 5,
#  "depression 're": 5,
#  'teen depression': 5,
#  'depression recovery': 5,
#  'depression joke': 5,
#  'manic depression': 5,
#  'depression â\x80\x93': 5,
#  "'ve depression": 5,
#  'deepika padukone': 5,
#  'depression struggle': 5,
#  "n't blend": 5,
#  'anxiety https': 5,
#  'infinity war': 5,
#  'pointing backhand': 5,
#  'backhand index': 5,
#  'death death': 5,
#  'caused depression': 5,
#  'face open': 5,
#  'got depression': 4,
#  'hands sign': 4,
#  'sign emoji': 4,
#  'depression got': 4,
#  'people suffer': 4,
#  'disorder depression': 4,
#  'much better': 4,
#  'depression etc': 4,
#  'depression going': 4,
#  'mindfulness therapy': 4,
#  "n't see": 4,
#  'emoji cherry': 4,
#  'bad day': 4,
#  'emoji airplane': 4,
#  'fix depression': 4,
#  "really n't": 4,
#  'want know': 4,
#  "n't wait": 4,
#  'took depression': 4,
#  'battling depression': 4,
#  'depression sadness': 4,
#  'depression read': 4,
#  '1-800-273-8255 suicide': 4,
#  'depression low': 4,
#  'good luck': 4,
#  'side effects': 4,
#  'depression obsession': 4,
#  'never heard': 4,
#  "hope n't": 4,
#  "n't eat": 4,
#  'anything else': 4,
#  'last year': 4,
#  'depression trauma': 4,
#  'depression please': 4,
#  'exercise prevent': 4,
#  'long term': 4,
#  "n't worry": 4,
#  'hit like': 4,
#  'stock market': 4,
#  'pretty sure': 4,
#  'depression pain': 4,
#  'know someone': 4,
#  'anxiety panic': 4,
#  'sadness depression': 4,
#  "n't help": 4,
#  'diagnosed depression': 4,
#  'depression years': 4,
#  'make fun': 4,
#  'keep going': 4,
#  'bad depression': 4,
#  'love much': 4,
#  'hate depression': 4,
#  'depression eating': 4,
#  'depression bad': 4,
#  'men differ': 4,
#  'differ women': 4,
#  'women https': 4,
#  'https //ift.tt/2humcsyâ': 4,
#  'old friend': 4,
#  'people like': 4,
#  'life also': 4,
#  'think depression': 4,
#  'things like': 4,
#  "n't wan": 4,
#  'depression rise': 4,
#  'via etsy': 4,
#  'physical health': 4,
#  'first time': 4,
#  'life ...': 4,
#  'social anxiety': 4,
#  "'ve never": 4,
#  'face halo': 4,
#  'anxiety mental': 4,
#  'shows promise': 4,
#  'health https': 4,
#  "n't stop": 4,
#  'higher rates': 4,
#  'taking depression': 4,
#  'state depression': 4,
#  "shit n't": 4,
#  'suicidal depression': 4,
#  'depression young': 4,
#  'lonely millennials': 4,
#  'depression comes': 4,
#  'suffers depression': 4,
#  "bitch n't": 4,
#  "n't feel": 4,
#  '... http': 4,
#  'cole talks': 4,
#  'depression married': 4,
#  'married life': 4,
#  'new rappers': 4,
#  "someone n't": 4,
#  'depression vaastu': 4,
#  'depression came': 4,
#  'http //bit.ly/2k3w5hjâ': 4,
#  'let know': 4,
#  'depressive symptoms': 4,
#  'https //medium.com/': 4,
#  "n't sleep": 4,
#  'emoji smirking': 4,
#  'smirking face': 4,
#  'state mind': 4,
#  'depression life': 4,
#  'disappointed face': 4,
#  'comes depression': 4,
#  'spend time': 4,
#  "illness n't": 4,
#  '... â\x80\x94': 4,
#  'depression actually': 4,
#  'depression today': 4,
#  "n't care": 4,
#  'suffer anxiety': 4,
#  'helps depression': 4,
#  'emoji man': 4,
#  'wave depression': 4,
#  'emoji fire': 4,
#  'anxiety suicidal': 4,
#  'depression villainous': 4,
#  'villainous state': 4,
#  'http //www.cbc.ca/news/health/exercise-depression-prevention-1.4634002â': 4,
#  '//www.cbc.ca/news/health/exercise-depression-prevention-1.4634002â â\x80¦': 4,
#  'https //twitter.com/ayanatheoracle/status/988861135142248449â': 4,
#  '//twitter.com/ayanatheoracle/status/988861135142248449â â\x80¦': 4,
#  'leads depression': 4,
#  'nothing wrong': 4,
#  'looks like': 4,
#  'https //www.thesun.co.uk/news/6137739/cannabis-ease-depression-stress-anxiety/â': 4,
#  '//www.thesun.co.uk/news/6137739/cannabis-ease-depression-stress-anxiety/â â\x80¦': 4,
#  'suicide depression': 4,
#  'anxiety ptsd': 4,
#  'understand depression': 4,
#  'exercise lowers': 4,
#  'lowers risk': 4,
#  'ages researchers': 4,
#  'researchers find': 4,
#  'find http': 4,
#  'depression let': 4,
#  'chronic pain': 4,
#  'causing depression': 4,
#  'depression hard': 3,
#  'need depression': 3,
#  'emoji clapping': 3,
#  'clapping hands': 3,
#  'anxiety disorder': 3,
#  'one cares': 3,
#  'mentalillness bipolar': 3,
#  'improve depression': 3,
#  "n't work": 3,
#  'therapy via': 3,
#  'via skype': 3,
#  'skype therapy': 3,
#  'therapy session': 3,
#  'depression lonely': 3,
#  'think people': 3,
#  'life sucks': 3,
#  'depression decided': 3,
#  'someone like': 3,
#  'depression give': 3,
#  "day n't": 3,
#  "'re going": 3,
#  'help emoji': 3,
#  'blossom emoji': 3,
#  'depression kicking': 3,
#  'saved depression': 3,
#  'depression anger': 3,
#  'going emoji': 3,
#  'use depression': 3,
#  "n't always": 3,
#  'depression great': 3,
#  'depression ocd': 3,
#  "n't fix": 3,
#  'suicide hotline877-226-3111': 3,
#  'hotline877-226-3111 addiction': 3,
#  'addiction hotline844-228-2962': 3,
#  'hotline844-228-2962 eating': 3,
#  'disorder hotline877-455-0628': 3,
#  'hotline877-455-0628 self': 3,
#  'harm hotline888-640-5174': 3,
#  'hotline888-640-5174 depression': 3,
#  'hotlineshare someone': 3,
#  'someone might': 3,
#  'might really': 3,
#  'really need': 3,
#  'need phone': 3,
#  'phone numbers': 3,
#  'depression exercise': 3,
#  'exercise decreases': 3,
#  'decreases chance': 3,
#  'depression later': 3,
#  'later life': 3,
#  'jokes depression': 3,
#  'another great': 3,
#  'suffering chronic': 3,
#  'https //vine.co/v/iu3l2lpbhikâ': 3,
#  "n't like": 3,
#  "know 're": 3,
#  'depression lmao': 3,
#  'depression someone': 3,
#  'health problems': 3,
#  'emoji persevering': 3,
#  'persevering face': 3,
#  "n't anything": 3,
#  'lead depression': 3,
#  'depression symptoms': 3,
#  "one n't": 3,
#  'health care': 3,
#  'children mental': 3,
#  'depression lives': 3,
#  'one day': 3,
#  'emoji sleeping': 3,
#  'sleeping face': 3,
#  'depression know': 3,
#  'depression instead': 3,
#  'nice see': 3,
#  'wants see': 3,
#  'like truck': 3,
#  'sign depression': 3,
#  'emoji tired': 3,
#  'tired face': 3,
#  "n't matter": 3,
#  'even though': 3,
#  'depression thoughts': 3,
#  'depression trying': 3,
#  'mothers avoid': 3,
#  'avoid nighttime': 3,
#  'nighttime breastfeeding': 3,
#  'breastfeeding decrease': 3,
#  'decrease risk': 3,
#  'depression free': 3,
#  'free handout': 3,
#  'handout share': 3,
#  'share print': 3,
#  'print http': 3,
#  '//ow.ly/le9p30jf99gâ breastfeeding': 3,
#  'breastfeeding nursing': 3,
#  'nursing sleep': 3,
#  'sleep mother': 3,
#  'mother baby': 3,
#  'questions http': 3,
#  'another day': 3,
#  'worst thing': 3,
#  'realize depression': 3,
#  'take break': 3,
#  'anxiety attacks': 3,
#  'depression lol': 3,
#  'like postpartum': 3,
#  'depression sickness': 3,
#  'depression sleep': 3,
#  'emoji sparkling': 3,
#  'sparkling heart': 3,
#  'let get': 3,
#  'gon take': 3,
#  'escape depression': 3,
#  'relieved face': 3,
#  "n't say": 3,
#  'come depression': 3,
#  'diary journal': 3,
#  'things ...': 3,
#  'reduces depression': 3,
#  'depression risk': 3,
#  "n't understand": 3,
#  'depression worse': 3,
#  "things n't": 3,
#  'imbalance brain': 3,
#  'feel lost': 3,
#  'left behind': 3,
#  'mentalhealth mentalhealthawareness': 3,
#  'attempted suicide': 3,
#  'summer depression': 3,
#  'depression still': 3,
#  "n't deserve": 3,
#  'per day': 3,
#  'hit depression': 3,
#  'depression want': 3,
#  'anchor hocking': 3,
#  'pink depression': 3,
#  'beat depression': 3,
#  'symptoms anxiety': 3,
#  "sad n't": 3,
#  "n't forget": 3,
#  'living depression': 3,
#  'like ...': 3,
#  'next week': 3,
#  'depression mania': 3,
#  "like n't": 3,
#  'sleepless nights': 3,
#  "like 've": 3,
#  'leave bed': 3,
#  'overcome depression': 3,
#  'last night': 3,
#  'cope depression': 3,
#  'gave depression': 3,
#  'high school': 3,
#  'ketamine nasal': 3,
#  'nasal spray': 3,
#  'spray shows': 3,
#  'promise depression': 3,
#  'suicide health': 3,
#  'sexual minority': 3,
#  'right emoji': 3,
#  'depression well': 3,
#  'wish people': 3,
#  'depression seriously': 3,
#  "n't one": 3,
#  'really bad': 3,
#  'medication depression': 3,
#  'stuff like': 3,
#  'young people': 3,
#  'would say': 3,
#  'millennials twice': 3,
#  'twice likely': 3,
#  'likely experience': 3,
#  'anxiety finds': 3,
#  'finds study': 3,
#  '//www.independent.co.uk/life-style/millennials-lonely-depression-anxiety-mental-health-odds-doubling-unemployed-study-a8319686.htmlâ â\x80¦': 3,
#  'depression kicks': 3,
#  'due depression': 3,
#  'feel lot': 3,
#  'treating depression': 3,
#  'depression music': 3,
#  "think 'll": 3,
#  "right n't": 3,
#  'depression without': 3,
#  'since depression': 3,
#  'pain depression': 3,
#  'mother depression': 3,
#  'depression back': 3,
#  'someone would': 3,
#  'depression bitch': 3,
#  'interview https': 3,
#  'anxiety patients': 3,
#  'https //twitter.com/kanyewest/status/989153701095915522â': 3,
#  '//twitter.com/kanyewest/status/989153701095915522â â\x80¦': 3,
#  'thinking depression': 3,
#  'treatment depression': 3,
#  'depression thanks': 3,
#  'tms therapy': 3,
#  'option depression': 3,
#  'today https': 3,
#  "n't really": 3,
#  'year ago': 3,
#  "think 're": 3,
#  'dont want': 3,
#  'chat teen': 3,
#  'depression lead': 3,
#  'visit http': 3,
#  'older adults': 3,
#  'pretty much': 3,
#  'anxiety help': 3,
#  'hard work': 3,
#  'depression honestly': 3,
#  'emoji sleepy': 3,
#  'sleepy face': 3,
#  'cleared skin': 3,
#  'depression come': 3,
#  'please pray': 3,
#  'depression especially': 3,
#  'depression serious': 3,
#  'mental illnesses': 3,
#  'days depression': 3,
#  'loved ones': 3,
#  'actual depression': 3,
#  'pointing index': 3,
#  'rappers rare': 3,
#  'rare interview': 3,
#  'symptoms https': 3,
#  'depression man': 3,
#  'million people': 3,
#  "even n't": 3,
#  'somebody else': 3,
#  "'ve ever": 3,
#  'feeling good': 3,
#  'keep depression': 3,
#  'rid depression': 3,
#  'struggled depression': 3,
#  'honestly think': 3,
#  'depression maybe': 3,
#  'good way': 3,
#  'depression sad': 3,
#  'â\x80¦ depression': 3,
#  'care depression': 3,
#  'shoutout depression': 3,
#  'happiness depression': 3,
#  'junk food': 3,
#  'depression loneliness': 3,
#  'suicide hotline': 3,
#  'class depression': 3,
#  'loneliness depression': 3,
#  'severe anxiety': 3,
#  'one depression': 3,
#  "'ve gone": 3,
#  'cannabis easeâ': 3,
#  'easeâ depression': 3,
#  'suicide https': 3,
#  'survived depression': 3,
#  'emoji raised': 3,
#  'falling depression': 3,
#  'depression easy': 3,
#  'depression love': 3,
#  'avoid depression': 3,
#  'type depression': 3,
#  'raise awareness': 3,
#  'ask effective': 3,
#  'effective methods': 3,
#  'methods fight': 3,
#  'emoji unamused': 3,
#  'unamused face': 3,
#  'depression thing': 3,
#  'exercise helps': 3,
#  'bateman lectures': 3,
#  'lectures depression': 3,
#  'show support': 3,
#  'face rolling': 3,
#  'rolling eyes': 3,
#  'awg_allan telegramsam100': 3,
#  'depression mood': 3,
#  'depression already': 3,
#  'http //socsi.in/32qe1â': 3,
#  'start day': 3,
#  'like something': 3,
#  'every day': 3,
#  '... actually': 3,
#  'exercising slash': 3,
#  'slash risk': 3,
#  'answer questions': 3,
#  'mentalhealth adhd': 3,
#  'adhd stress': 3,
#  'ptsd selfesteem': 3,
#  'selfesteem familyconflicts': 3,
#  'familyconflicts counseling': 3,
#  'counseling bipolar': 3,
#  'bipolar therapy': 3,
#  'therapy retweet': 3,
#  'retweet followus': 3,
#  'followus decatur': 3,
#  'decatur atlanta': 3,
#  'atlanta georgia': 3,
#  'emoji purple': 3,
#  'purple heart': 3,
#  'social epidemic': 3,
#  'epidemic doubles': 3,
#  'doubles depression': 3,
#  'anxiety risk': 3,
#  'risk https': 3,
#  'depression affects': 3,
#  'cancer https': 3,
#  "would n't": 3,
#  'take care': 3,
#  'depression ages': 3,
#  'lot people': 3,
#  'join nimhgov': 3,
#  'nimhgov twitter': 3,
#  'nimh experts': 3,
#  "'ve suffered": 3,
#  'know say': 3,
#  'say depression': 3,
#  'hand medium': 3,
#  'third great': 3,
#  'rise far-right': 3,
#  'far-right experiences': 3,
#  'experiences turkey': 3,
#  'rock bottom': 3,
#  'end depression': 3,
#  'well ...': 3,
#  'new blog': 3,
#  '... health': 3,
#  'lower risk': 3,
#  'treat depression': 3,
#  'try get': 3,
#  'study http': 3,
#  'depression shit': 3,
#  'depression addiction': 3,
#  'https //www.bmj.com/content/361/bmj.k1415â': 3,
#  '//www.bmj.com/content/361/bmj.k1415â â\x80¦': 3,
#  'much emoji': 3,
#  'depression matter': 3,
#  'matter age': 3,
#  'age gender': 3,
#  'zicutake depression': 3,
#  'depression prevented': 3,
#  'prevented exercise': 3,
#  'exercise https': 3,
#  'https //goo.gl/fb/mu7k6tâ': 3,
#  'got hit': 3,
#  'blog depression': 3,
#  'hearts emoji': 3,
#  'anxiety sun': 3,
#  'sun https': 3,
#  'emoji beating': 3,
#  'beating heart': 3,
#  'man running': 3,
#  'https //ift.tt/2qyemo7â': 3,
#  'federal reserve': 3,
#  'reserve caused': 3,
#  'mouth smiling': 3,
#  'lack understanding': 2,
#  'parents depression': 2,
#  'hard get': 2,
#  'people understand': 2,
#  "something n't": 2,
#  'depression meds': 2,
#  'depression fighting': 2,
#  'suddenly cured': 2,
#  'look depression': 2,
#  'head wall': 2,
#  'think would': 2,
#  'would know': 2,
#  'else every': 2,
#  'got help': 2,
#  'depression find': 2,
#  'feeling depression': 2,
#  'wan see': 2,
#  'talk mental': 2,
#  "depressed n't": 2,
#  "n't control": 2,
#  'control depression': 2,
#  'crazy much': 2,
#  'feel much': 2,
#  'know going': 2,
#  'kanye west': 2,
#  'liking trump': 2,
#  'spiral depression': 2,
#  'depression brain': 2,
#  "n't tell": 2,
#  'tell god': 2,
#  'depression borderlinepersonality': 2,
#  'borderlinepersonality mentalillness': 2,
#  'move depression': 2,
#  'anxiety insecurity': 2,
#  'insecurity depression': 2,
#  'depression meditation': 2,
#  'day day': 2,
#  'bbcone hughfw': 2,
#  'hughfw jamieoliver': 2,
#  'feel guilty': 2,
#  'people see': 2,
#  'see big': 2,
#  'big improvements': 2,
#  'improvements within': 2,
#  'within 3-4': 2,
#  '3-4 weeks': 2,
#  'weeks contact': 2,
#  'contact learn': 2,
#  'learn schedule': 2,
#  'schedule skype': 2,
#  'session https': 2,
#  'heart grow': 2,
#  'never better': 2,
#  'depression sometimes': 2,
#  'need someone': 2,
#  'room full': 2,
#  "'ll spiral": 2,
#  'person life': 2,
#  'lot times': 2,
#  'something else': 2,
#  'depression nightmares': 2,
#  'time anxiety': 2,
#  'emoji sunflower': 2,
#  'day write': 2,
#  'weekend depression': 2,
#  'kicking ass': 2,
#  'still want': 2,
#  'coming back': 2,
#  'back emoji': 2,
#  'point trying': 2,
#  "know 'll": 2,
#  'depression era': 2,
#  'tears left': 2,
#  'left cry': 2,
#  '... get': 2,
#  "'ll try": 2,
#  'best help': 2,
#  'depression since': 2,
#  'many years': 2,
#  "'ll never": 2,
#  'people use': 2,
#  'depression epic': 2,
#  "since 've": 2,
#  'depression speaking': 2,
#  'time since': 2,
#  'store day': 2,
#  'want meet': 2,
#  'whole depression': 2,
#  'keeps depression': 2,
#  'back ground': 2,
#  'banning guns': 2,
#  "guns n't": 2,
#  'would fix': 2,
#  'fix everything': 2,
#  'everything https': 2,
#  'depression hotlineshare': 2,
#  'numbers right': 2,
#  'model depression': 2,
#  'mentality life': 2,
#  'many people': 2,
#  'health break': 2,
#  'depression truly': 2,
#  'https //twitter.com/kimkardashian/status/989220790741553152â': 2,
#  '//twitter.com/kimkardashian/status/989220790741553152â â\x80¦': 2,
#  'great repub': 2,
#  'popehat zentropy_': 2,
#  'people work': 2,
#  'work depression': 2,
#  'depression hate': 2,
#  'good look': 2,
#  'thoughts depression': 2,
#  "work n't": 2,
#  'effects include': 2,
#  'happy birthday': 2,
#  'anymore want': 2,
#  'depression world': 2,
#  'worst depression': 2,
#  'emoji skull': 2,
#  'depression parents': 2,
#  'changed life': 2,
#  'three common': 2,
#  'common misconceptions': 2,
#  'misconceptions depression': 2,
#  'eating habits': 2,
#  'health depression': 2,
#  'suffering mental': 2,
#  'illness called': 2,
#  'get help': 2,
#  'youtube channel': 2,
#  'went depression': 2,
#  'depression mode': 2,
#  'emoji sneezing': 2,
#  'sneezing face': 2,
#  'emoji hundred': 2,
#  'hundred points': 2,
#  'points symbol': 2,
#  'depression creeping': 2,
#  'year life': 2,
#  'depression daily': 2,
#  'turned depression': 2,
#  'people actually': 2,
#  'actually struggle': 2,
#  'fact person': 2,
#  'fucking real': 2,
#  'mentalhealth mentalhealthmatters': 2,
#  'let hope': 2,
#  'temporary depression': 2,
#  "know n't": 2,
#  'blood test': 2,
#  'depression cause': 2,
#  'negative energy': 2,
#  'real serious': 2,
#  'stop making': 2,
#  'depression jokes': 2,
#  'anxiety well': 2,
#  'spent last': 2,
#  'health anxiety': 2,
#  'since 2016': 2,
#  'far depression': 2,
#  'nights depression': 2,
#  'love give': 2,
#  'started one': 2,
#  'regarding depression': 2,
#  'depression â\x80\x94': 2,
#  'tell anyone': 2,
#  'anything depression': 2,
#  'well depression': 2,
#  'ptsd depression': 2,
#  'anger depression': 2,
#  '... start': 2,
#  'sad depression': 2,
#  'nap time': 2,
#  'time emoji': 2,
#  'insomnia depression': 2,
#  "'re one": 2,
#  'anxiety real': 2,
#  'live depression': 2,
#  'depression fix': 2,
#  'depression top': 2,
#  'disease https': 2,
#  'without medication': 2,
#  'depression pills': 2,
#  '... point': 2,
#  'hpv vax': 2,
#  'immune system': 2,
#  'someone took': 2,
#  'took years': 2,
#  'made feel': 2,
#  'like failure': 2,
#  "n't settle": 2,
#  'settle depression': 2,
#  'anxiety defeat': 2,
#  'defeat jesus': 2,
#  'jesus wants': 2,
#  'wants overcome': 2,
#  'overcome faith': 2,
#  ...}

# %%
# 2-gram words yang memiliki label non-depressive, sort by value
x = sc_tf_idf.tf_positive
{k: v for k, v in sorted(x.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'good morning': 83,
#  "n't wait": 67,
#  '... ...': 61,
#  'last night': 51,
#  'good night': 38,
#  'happy birthday': 37,
#  'getting ready': 35,
#  "n't know": 33,
#  'good luck': 33,
#  "... n't": 33,
#  'cant wait': 31,
#  'looking forward': 28,
#  'let know': 27,
#  'great day': 25,
#  'good day': 25,
#  'quot quot': 24,
#  '... good': 22,
#  'get 100': 22,
#  'sounds like': 21,
#  "n't get": 21,
#  'wait see': 20,
#  'mothers day': 20,
#  '100 followers': 20,
#  'followers day': 20,
#  'day using': 20,
#  'add everyone': 20,
#  'everyone train': 20,
#  'train pay': 20,
#  'pay vip': 20,
#  'much fun': 19,
#  '... love': 19,
#  "hope 're": 18,
#  'happy mothers': 18,
#  'beautiful day': 18,
#  'next time': 17,
#  'first time': 17,
#  'ice cream': 17,
#  'much better': 17,
#  'next week': 17,
#  '... http': 16,
#  'lol ...': 16,
#  'going bed': 16,
#  'make sure': 15,
#  'one day': 15,
#  'thank much': 15,
#  "'ve got": 15,
#  'got home': 15,
#  'last day': 15,
#  'going see': 15,
#  'day today': 14,
#  "n't worry": 14,
#  'best friend': 14,
#  '... lol': 14,
#  'good time': 13,
#  "could n't": 13,
#  'looks like': 13,
#  'good one': 13,
#  'today ...': 13,
#  '... quot': 13,
#  'jonas brothers': 13,
#  'using www.tweeteradder.com': 13,
#  'www.tweeteradder.com add': 13,
#  "think 'll": 12,
#  'work ...': 12,
#  'feel like': 12,
#  'thank god': 12,
#  'made day': 12,
#  'first day': 12,
#  'good times': 11,
#  'good thing': 11,
#  'well done': 11,
#  'great time': 11,
#  'wish luck': 11,
#  'feel better': 11,
#  'thanks follow': 11,
#  'new album': 11,
#  'day ...': 11,
#  'life good': 11,
#  'mcflyforgermany mcflyforgermany': 11,
#  "n't even": 10,
#  "'ll get": 10,
#  'new moon': 10,
#  'pretty good': 10,
#  'thanks much': 10,
#  "n't forget": 10,
#  '... got': 10,
#  'long time': 10,
#  'long weekend': 10,
#  'glad hear': 10,
#  'mother day': 10,
#  'haha ...': 10,
#  'got back': 10,
#  'pretty much': 10,
#  'day work': 10,
#  'love guys': 10,
#  '... know': 9,
#  'last time': 9,
#  'take care': 9,
#  'school ...': 9,
#  'well ...': 9,
#  'morning everyone': 9,
#  '... really': 9,
#  '... well': 9,
#  'really good': 9,
#  'look forward': 9,
#  "n't like": 9,
#  "'re welcome": 9,
#  'wait till': 9,
#  'would like': 9,
#  'wish could': 9,
#  "n't think": 9,
#  'haha love': 9,
#  'mtv movie': 9,
#  'movie awards': 9,
#  "n't want": 9,
#  'wait ...': 8,
#  'work today': 8,
#  'hope everyone': 8,
#  '... hope': 8,
#  'good ...': 8,
#  'amp amp': 8,
#  'day school': 8,
#  'ready work': 8,
#  'know right': 8,
#  'get back': 8,
#  'come back': 8,
#  "would n't": 8,
#  'know ...': 8,
#  'thanks guys': 8,
#  "'re gon": 8,
#  'going sleep': 8,
#  'going get': 8,
#  "n't believe": 8,
#  '... time': 8,
#  'got get': 8,
#  'sweet dreams': 7,
#  'really love': 7,
#  'love new': 7,
#  'new song': 7,
#  "maybe 'll": 7,
#  "... 're": 7,
#  'back work': 7,
#  'feeling better': 7,
#  "lol n't": 7,
#  'get sleep': 7,
#  'live http': 7,
#  'would love': 7,
#  'star trek': 7,
#  'night ...': 7,
#  "n't see": 7,
#  "... 'll": 7,
#  'morning twitter': 7,
#  'week ...': 7,
#  'look like': 7,
#  '... yay': 7,
#  'makes feel': 7,
#  "'re awesome": 7,
#  "'ll keep": 7,
#  'thanks followfriday': 7,
#  "'ll see": 7,
#  'good see': 7,
#  'feels good': 7,
#  "n't feel": 7,
#  'going make': 7,
#  'time bed': 7,
#  'quot http': 7,
#  '... nice': 7,
#  'hope great': 7,
#  'home ...': 7,
#  'good idea': 7,
#  'joined twitter': 7,
#  "'ll let": 7,
#  'back home': 7,
#  'night museum': 7,
#  'haha thanks': 7,
#  'finally got': 7,
#  'time get': 7,
#  'using www.tweeterfollow.com': 7,
#  'www.tweeterfollow.com add': 7,
#  'new job': 6,
#  'still love': 6,
#  'get done': 6,
#  'god bless': 6,
#  '... still': 6,
#  'really want': 6,
#  'went well': 6,
#  "'ll take": 6,
#  'came home': 6,
#  'hope like': 6,
#  "think 're": 6,
#  'welcome back': 6,
#  'going watch': 6,
#  'want one': 6,
#  'get used': 6,
#  'see lol': 6,
#  'forward seeing': 6,
#  'new twitter': 6,
#  'glad liked': 6,
#  'another day': 6,
#  'everyone else': 6,
#  'need get': 6,
#  'sounds good': 6,
#  'twitter ...': 6,
#  'nice meet': 6,
#  'hope well': 6,
#  'hope good': 6,
#  'bank holiday': 6,
#  'thank goodness': 6,
#  'get home': 6,
#  'love song': 6,
#  'fun today': 6,
#  'happy mother': 6,
#  'even though': 6,
#  'quot lol': 6,
#  'love quot': 6,
#  '... like': 6,
#  'get ready': 6,
#  'thank thank': 6,
#  'wan see': 6,
#  'got done': 6,
#  "n't stop": 6,
#  'big day': 6,
#  'guys amazing': 6,
#  "n't let": 6,
#  'tweet tweet': 6,
#  'new york': 6,
#  'time see': 6,
#  'fun fun': 6,
#  'soon ...': 6,
#  'last year': 6,
#  "'re right": 6,
#  "'ll try": 6,
#  '... going': 6,
#  'day weekend': 6,
#  'trying get': 6,
#  'gon watch': 6,
#  'follow friday': 6,
#  'lol thanks': 6,
#  '30secondstomars 30secondstomars': 6,
#  'drag hell': 6,
#  'harry potter': 6,
#  'time ...': 6,
#  'make laugh': 5,
#  'twitter page': 5,
#  'tomorrow ...': 5,
#  'nothing like': 5,
#  'like good': 5,
#  "'ll tweet": 5,
#  '... maybe': 5,
#  'totally agree': 5,
#  "'re great": 5,
#  'right back': 5,
#  'busy day': 5,
#  'going well': 5,
#  'blog post': 5,
#  "n't really": 5,
#  'thanks following': 5,
#  "n't sleep": 5,
#  'tonight ...': 5,
#  'long day': 5,
#  'today good': 5,
#  'good stuff': 5,
#  'happy sunday': 5,
#  "n't make": 5,
#  'new followers': 5,
#  'know want': 5,
#  'amp get': 5,
#  'pretty cool': 5,
#  'sun shining': 5,
#  'going back': 5,
#  'wedding anniversary': 5,
#  'twitter world': 5,
#  'hard work': 5,
#  'better soon': 5,
#  'nothing better': 5,
#  'see guys': 5,
#  'quot ...': 5,
#  'night everyone': 5,
#  "know 're": 5,
#  'home work': 5,
#  '... happy': 5,
#  'woo hoo': 5,
#  'anyone else': 5,
#  "n't say": 5,
#  'great night': 5,
#  "'re enjoying": 5,
#  'love much': 5,
#  'work week': 5,
#  'hannah montana': 5,
#  'fun time': 5,
#  'like one': 5,
#  'gon get': 5,
#  'days till': 5,
#  'like see': 5,
#  'think going': 5,
#  'wonderful day': 5,
#  'one best': 5,
#  "'re cute": 5,
#  'early night': 5,
#  'quot love': 5,
#  'sway sway': 5,
#  'friday night': 5,
#  'lol yes': 5,
#  'lol well': 5,
#  '... feel': 5,
#  'time year': 5,
#  'lol yeah': 5,
#  'sooo much': 5,
#  'know think': 5,
#  'good hear': 5,
#  'year ...': 5,
#  'day tomorrow': 5,
#  'dont know': 5,
#  'bed ...': 5,
#  'like new': 5,
#  'lol one': 5,
#  'spent day': 5,
#  'glad know': 5,
#  'day new': 5,
#  'work going': 5,
#  'nice day': 5,
#  'feel good': 5,
#  "really n't": 5,
#  'wedding day': 5,
#  '... thank': 5,
#  'blessed day': 5,
#  'sleep ...': 5,
#  'hope get': 5,
#  "'re sweet": 5,
#  'good mood': 5,
#  'play guitar': 5,
#  'great job': 5,
#  'got new': 5,
#  'love ...': 5,
#  "know n't": 5,
#  'back ...': 5,
#  'even know': 5,
#  'good things': 5,
#  '... nothing': 5,
#  'though ...': 5,
#  'year old': 5,
#  'shop shop': 5,
#  '... best': 5,
#  '... back': 5,
#  'amazing ...': 5,
#  'pretty please': 5,
#  'crazy day': 5,
#  'star wars': 4,
#  'quite like': 4,
#  'day good': 4,
#  'love music': 4,
#  'thanks appreciate': 4,
#  'appreciate feedback': 4,
#  'love songs': 4,
#  'days ...': 4,
#  'hours sleep': 4,
#  'safe trip': 4,
#  'want see': 4,
#  "'ll make": 4,
#  'great morning': 4,
#  '... made': 4,
#  'going mall': 4,
#  'could use': 4,
#  'old school': 4,
#  'awww thanks': 4,
#  'night good': 4,
#  'love see': 4,
#  'spending day': 4,
#  'giving away': 4,
#  'wait til': 4,
#  'know could': 4,
#  '... .and': 4,
#  'thought might': 4,
#  'tweet ...': 4,
#  'next year': 4,
#  'got love': 4,
#  'school today': 4,
#  'hey hey': 4,
#  'getting better': 4,
#  'hey monday': 4,
#  'amazing day': 4,
#  'lol see': 4,
#  '... yes': 4,
#  'love work': 4,
#  'fun love': 4,
#  'gon good': 4,
#  'watching movies': 4,
#  'yes ...': 4,
#  "quot n't": 4,
#  'really great': 4,
#  'great song': 4,
#  'morning tweeps': 4,
#  'good thanks': 4,
#  "good 'll": 4,
#  'great friends': 4,
#  'friends ...': 4,
#  "n't care": 4,
#  "'ll find": 4,
#  'morning world': 4,
#  'sunday afternoon': 4,
#  'last minute': 4,
#  'still got': 4,
#  'years ago': 4,
#  'watch movies': 4,
#  'rest day': 4,
#  'playing sims': 4,
#  'bed watching': 4,
#  'watching movie': 4,
#  'want get': 4,
#  'get free': 4,
#  'excited see': 4,
#  'get twitter': 4,
#  "n't read": 4,
#  'lets see': 4,
#  'well good': 4,
#  'movie quot': 4,
#  'many times': 4,
#  "well n't": 4,
#  "'ll give": 4,
#  '... least': 4,
#  'would fun': 4,
#  'really bad': 4,
#  'get rest': 4,
#  'two days': 4,
#  'take shower': 4,
#  'day going': 4,
#  'amazing night': 4,
#  'haha like': 4,
#  'nice see': 4,
#  'feel free': 4,
#  'please say': 4,
#  'going work': 4,
#  'fun last': 4,
#  'really appreciate': 4,
#  "n't bother": 4,
#  'glad like': 4,
#  'try get': 4,
#  "'ve decided": 4,
#  'yay love': 4,
#  'good good': 4,
#  'amp maybe': 4,
#  'love job': 4,
#  'thanks good': 4,
#  'please http': 4,
#  'hope goes': 4,
#  "hope 'll": 4,
#  'pack pack': 4,
#  'hope feel': 4,
#  'glad see': 4,
#  'twitter account': 4,
#  'great news': 4,
#  'home fun': 4,
#  'really nice': 4,
#  'one days': 4,
#  'best friends': 4,
#  'quot haha': 4,
#  'coming back': 4,
#  'cool love': 4,
#  '*knocks* declan': 4,
#  'lol love': 4,
#  'look http': 4,
#  'said quot': 4,
#  'last week': 4,
#  'time work': 4,
#  'got make': 4,
#  'hee hee': 4,
#  'lot better': 4,
#  'every day': 4,
#  'even better': 4,
#  'last nite': 4,
#  'get better': 4,
#  'watch movie': 4,
#  '... finally': 4,
#  'either way': 4,
#  'taylor swift': 4,
#  "n't seen": 4,
#  "'ve ever": 4,
#  'playing piano': 4,
#  '... great': 4,
#  "glad 're": 4,
#  'pretty sure': 4,
#  'fall asleep': 4,
#  "hope n't": 4,
#  'bad ...': 4,
#  'made laugh': 4,
#  "n't tell": 4,
#  'makes smile': 4,
#  'would say': 4,
#  'see everyone': 4,
#  'haha well': 4,
#  'something like': 4,
#  'one love': 4,
#  'name ...': 4,
#  'amazing love': 4,
#  'love lol': 4,
#  'going good': 4,
#  'think might': 4,
#  'day outside': 4,
#  'lol good': 4,
#  'someone else': 4,
#  'right love': 4,
#  'perfect day': 4,
#  'probably get': 4,
#  'watching harry': 4,
#  '... ..i': 4,
#  'wan hear': 4,
#  'thanks everyone': 4,
#  'kristen stewart': 4,
#  'earn money': 4,
#  "n't mind": 4,
#  '... lovely': 4,
#  'hey thanks': 4,
#  'see ...': 4,
#  '... thanks': 4,
#  'later today': 4,
#  'school tomorrow': 4,
#  'need something': 4,
#  'trending topic': 4,
#  'wait get': 4,
#  'see later': 4,
#  'going swimming': 4,
#  'tomorrow night': 4,
#  'soo excited': 4,
#  'hey girl': 4,
#  "'ve never": 4,
#  'hmmm ...': 4,
#  'first one': 4,
#  "well 'll": 4,
#  'fun http': 4,
#  'social media': 4,
#  'nighty night': 4,
#  'thanks man': 4,
#  '... think': 4,
#  'never know': 4,
#  'blog http': 3,
#  "n't able": 3,
#  'see twitter': 3,
#  'cant see': 3,
#  'called quot': 3,
#  'good lol': 3,
#  'got one': 3,
#  'tired today': 3,
#  'two weeks': 3,
#  'check new': 3,
#  "sure n't": 3,
#  'today least': 3,
#  '... long': 3,
#  'listening music': 3,
#  'home today': 3,
#  'today work': 3,
#  'must get': 3,
#  'going take': 3,
#  '... work': 3,
#  'work days': 3,
#  'let see': 3,
#  'maybe ...': 3,
#  'goodnight everyone': 3,
#  "n't bad": 3,
#  "n't following": 3,
#  'french toast': 3,
#  '... even': 3,
#  'home made': 3,
#  'need find': 3,
#  'made twitter': 3,
#  'aww thanks': 3,
#  'two favorite': 3,
#  'miley cyrus': 3,
#  'day hope': 3,
#  'baby ...': 3,
#  'quot hey': 3,
#  "'re feeling": 3,
#  'help find': 3,
#  'hair cut': 3,
#  'sunny day': 3,
#  'wonderful weekend': 3,
#  'ill let': 3,
#  'post http': 3,
#  'yet got': 3,
#  'got reply': 3,
#  'fun night': 3,
#  'got see': 3,
#  'still waiting': 3,
#  'awesome time': 3,
#  'night tonight': 3,
#  "'ve finished": 3,
#  'ready bed': 3,
#  'cool cool': 3,
#  'got ...': 3,
#  'tomorrow good': 3,
#  'last nights': 3,
#  'night twitter': 3,
#  'feels like': 3,
#  'love haha': 3,
#  'big fan': 3,
#  'jonasbrothers http': 3,
#  'best mate': 3,
#  'fell asleep': 3,
#  'luck hope': 3,
#  'hope fun': 3,
#  "n't take": 3,
#  'erm ...': 3,
#  "n't miss": 3,
#  'lets hope': 3,
#  'thought maybe': 3,
#  'going home': 3,
#  'one ...': 3,
#  'baby daddy': 3,
#  'lol know': 3,
#  'amp love': 3,
#  'love life': 3,
#  '... excited': 3,
#  'quot thanks': 3,
#  'need know': 3,
#  'dont think': 3,
#  'movie ever': 3,
#  'thats good': 3,
#  'morning tweets': 3,
#  'today made': 3,
#  'drinking tea': 3,
#  '... pretty': 3,
#  "n't start": 3,
#  'hoping get': 3,
#  'monday morning': 3,
#  'morning feeling': 3,
#  "n't pick": 3,
#  'umm ...': 3,
#  'good news': 3,
#  'album today': 3,
#  'today got': 3,
#  'take deep': 3,
#  'enjoying nice': 3,
#  'great week': 3,
#  'got work': 3,
#  'funny day': 3,
#  'need sleep': 3,
#  'please keep': 3,
#  'hey whats': 3,
#  'weekend ...': 3,
#  'yes know': 3,
#  'please tell': 3,
#  '... right': 3,
#  'tomorrow going': 3,
#  'would cool': 3,
#  'bed time': 3,
#  'like quot': 3,
#  'really enjoyed': 3,
#  'time twitter': 3,
#  'today lol': 3,
#  'really need': 3,
#  'ready day': 3,
#  'till get': 3,
#  'got email': 3,
#  'least get': 3,
#  'rise shine': 3,
#  'soon hope': 3,
#  "n't complain": 3,
#  'customer service': 3,
#  "n't working": 3,
#  'tweet tomorrow': 3,
#  'way work': 3,
#  'work new': 3,
#  'man would': 3,
#  'would get': 3,
#  'sit outside': 3,
#  'follow twitter': 3,
#  'well worth': 3,
#  'home day': 3,
#  'real life': 3,
#  'gon buy': 3,
#  'wait days': 3,
#  "'ll probably": 3,
#  '... cant': 3,
#  'looks great': 3,
#  'amp watch': 3,
#  'well going': 3,
#  'goodnight world': 3,
#  'boom boom': 3,
#  'well guess': 3,
#  'try next': 3,
#  'please visit': 3,
#  'ipod touch': 3,
#  '... take': 3,
#  'today fun': 3,
#  "fun n't": 3,
#  'hello world': 3,
#  'looked like': 3,
#  'woop woop': 3,
#  'really sweet': 3,
#  'find new': 3,
#  'early sunday': 3,
#  "'re listening": 3,
#  'going use': 3,
#  'like watch': 3,
#  'buy new': 3,
#  "n't ask": 3,
#  "guess 'll": 3,
#  "'re fun": 3,
#  'laying bed': 3,
#  '... try': 3,
#  'holy shit': 3,
#  'song http': 3,
#  'album coming': 3,
#  "'ll leave": 3,
#  'good nite': 3,
#  "thanks n't": 3,
#  "day n't": 3,
#  'feel bad': 3,
#  'http //tweet.sg': 3,
#  'best day': 3,
#  'day ever': 3,
#  'gettin ready': 3,
#  'one lol': 3,
#  'good get': 3,
#  'day family': 3,
#  'family much': 3,
#  "'ve heard": 3,
#  'finally back': 3,
#  'day moms': 3,
#  'something else': 3,
#  'let guess': 3,
#  "'re good": 3,
#  'good friend': 3,
#  'hope dont': 3,
#  'hit sack': 3,
#  'day mom': 3,
#  'made breakfast': 3,
#  'quot good': 3,
#  'every year': 3,
#  'read tweets': 3,
#  'gift card': 3,
#  'know love': 3,
#  'outside sun': 3,
#  'night fever': 3,
#  'fever ...': 3,
#  'show ...': 3,
#  'good start': 3,
#  'thanks ...': 3,
#  'yet ...': 3,
#  'know goes': 3,
#  'night fun': 3,
#  'much love': 3,
#  'high school': 3,
#  'lol going': 3,
#  'went shopping': 3,
#  'need make': 3,
#  'song quot': 3,
#  'late night': 3,
#  'quot today': 3,
#  'every one': 3,
#  'thought would': 3,
#  "n't give": 3,
#  "man n't": 3,
#  'right ...': 3,
#  'family force': 3,
#  'went back': 3,
#  'back normal': 3,
#  'days ago': 3,
#  'dont worry': 3,
#  'morning ...': 3,
#  'get work': 3,
#  'hey guys': 3,
#  'haha gon': 3,
#  'make money': 3,
#  'goes well': 3,
#  'know know': 3,
#  'hey new': 3,
#  'friend ...': 3,
#  'true ...': 3,
#  'like really': 3,
#  'awesome ...': 3,
#  '... need': 3,
#  'day 2day': 3,
#  'love hope': 3,
#  'spread word': 3,
#  'thanks link': 3,
#  'world tour': 3,
#  "mom n't": 3,
#  'green tea': 3,
#  'thanks haha': 3,
#  'spend night': 3,
#  'living room': 3,
#  'show love': 3,
#  'half way': 3,
#  'come home': 3,
#  'soooo happy': 3,
#  'time today': 3,
#  'day quot': 3,
#  'good movie': 3,
#  "n't remember": 3,
#  '... sure': 3,
#  'almost done': 3,
#  'best things': 3,
#  'summer vacation': 3,
#  'one perks': 3,
#  'sitting sun': 3,
#  'lots fun': 3,
#  'today love': 3,
#  'twitter background': 3,
#  'beautiful today': 3,
#  'like right': 3,
#  'time going': 3,
#  'one personal': 3,
#  '... okay': 3,
#  'felt like': 3,
#  'watch new': 3,
#  "'re back": 3,
#  'something different': 3,
#  'thanks asking': 3,
#  'thanks comment': 3,
#  'good know': 3,
#  'back bed': 3,
#  'watch good': 3,
#  'say quot': 3,
#  "tomorrow 'll": 3,
#  'today great': 3,
#  'happy monday': 3,
#  'time low': 3,
#  'declan *knocks*': 3,
#  'way ...': 3,
#  'days left': 3,
#  "please 'll": 3,
#  'time start': 3,
#  'week school': 3,
#  'twitter friends': 3,
#  'still going': 3,
#  "n't poke": 3,
#  'poke bear': 3,
#  'today though': 3,
#  'road trip': 3,
#  'nice amp': 3,
#  '... would': 3,
#  'good quot': 3,
#  'hey nice': 3,
#  "'re still": 3,
#  "bad n't": 3,
#  'twitter followers': 3,
#  'awesome day': 3,
#  'people last': 3,
#  'get tweet': 3,
#  'time soon': 3,
#  'twitter got': 3,
#  'whole lot': 3,
#  'day http': 3,
#  'better ...': 3,
#  'much like': 3,
#  'finally done': 3,
#  "'ve done": 3,
#  'think saw': 3,
#  'sure ...': 3,
#  '... gon': 3,
#  'eat something': 3,
#  'happy amp': 3,
#  'holiday weekend': 3,
#  'get chance': 3,
#  "amp 'll": 3,
#  'made cry': 3,
#  'twitter like': 3,
#  'yet another': 3,
#  'hello new': 3,
#  'new video': 3,
#  'whole world': 3,
#  'world ...': 3,
#  'get see': 3,
#  'saturday morning': 3,
#  "tonight n't": 3,
#  'bed night': 3,
#  'way back': 3,
#  'used love': 3,
#  'fingers crossed': 3,
#  "n't wan": 3,
#  'like big': 3,
#  'love right': 3,
#  'late dinner': 3,
#  'still good': 3,
#  'looks good': 3,
#  'good nice': 3,
#  'thanks girl': 3,
#  'send back': 3,
#  'show tonight': 3,
#  'really tired': 3,
#  'quot little': 3,
#  'beautiful weather': 3,
#  'seems like': 3,
#  'yeah like': 3,
#  'almost time': 3,
#  "'ll wait": 3,
#  'coming soon': 3,
#  'today http': 3,
#  'gone ...': 3,
#  'good weekend': 3,
#  'use twitter': 3,
#  "'ll come": 3,
#  "'ll need": 3,
#  'yeah haha': 3,
#  'today first': 3,
#  'sounds fun': 3,
#  'nice weekend': 3,
#  'listening quot': 3,
#  'life like': 3,
#  'quot thank': 3,
#  'want quot': 3,
#  'glad back': 3,
#  'new blog': 3,
#  'please please': 3,
#  'home alone': 3,
#  'makes want': 3,
#  'day sun': 3,
#  'mission statement': 3,
#  '... get': 3,
#  'poor thing': 3,
#  'gon come': 3,
#  'twitter follow': 3,
#  'good deal': 3,
#  'lovely view': 3,
#  'care ...': 3,
#  'things love': 3,
#  'always good': 3,
#  'god http': 3,
#  'flight ...': 3,
#  'really cool': 3,
#  'morning hope': 3,
#  'get job': 3,
#  'please come': 3,
#  'one first': 3,
#  'today tomorrow': 3,
#  'amazing time': 3,
#  'like ...': 3,
#  'saturday afternoon': 3,
#  'hear well': 3,
#  'people follow': 3,
#  'love movie': 3,
#  'love twitter': 3,
#  'rock band': 3,
#  'think quot': 3,
#  'demi lovato': 3,
#  'better morning': 3,
#  'morning love': 3,
#  'nothing special': 3,
#  '... one': 3,
#  'fun tonight': 3,
#  "yeah n't": 3,
#  'great one': 3,
#  'lovely day': 3,
#  'enjoy sun': 3,
#  'quot many': 3,
#  "quot 'll": 3,
#  '... far': 3,
#  'far good': 3,
#  'see movie': 3,
#  '... hmm': 3,
#  'around ...': 3,
#  "'re going": 3,
#  'well glad': 3,
#  'blue sky': 3,
#  'times haha': 3,
#  'wake good': 3,
#  'yeah love': 3,
#  'getting married': 3,
#  'time got': 3,
#  'lets get': 3,
#  'get shower': 3,
#  'shower ...': 3,
#  'back soon': 3,
#  'front door': 3,
#  'gon love': 3,
#  '... totally': 3,
#  'bed good': 3,
#  'great weekend': 3,
#  'hills season': 3,
#  'two hours': 3,
#  'guess ...': 3,
#  'ready eat': 3,
#  'twitter profile': 3,
#  'got job': 3,
#  'please ...': 3,
#  "n't play": 3,
#  'note self': 3,
#  '... hello': 3,
#  'see http': 3,
#  'help get': 3,
#  'better day': 3,
#  "'ve missed": 3,
#  'super excited': 3,
#  'big big': 3,
#  "great n't": 3,
#  'one year': 3,
#  'stuck head': 3,
#  '... say': 3,
#  'wanted say': 3,
#  'haha hope': 3,
#  'haha yeah': 3,
#  'never knew': 3,
#  'best thing': 3,
#  'back lol': 3,
#  'quot know': 3,
#  'take pictures': 3,
#  'new one': 3,
#  'need new': 3,
#  'get bored': 3,
#  'good job': 3,
#  ...}
