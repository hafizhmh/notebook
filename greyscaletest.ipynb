# %%
# Hafizh Mulya H
# Update: 20 Agustus 2021
# grayscale test for google colab, pre-capstone
# live: https://colab.research.google.com/drive/16jmGlqrjKeAJicrXi6k08qbCKSh2fzfD?usp=sharing
from google.colab import files
from PIL import Image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a8eea80d-b50f-4bad-9f8f-3d5d0b24d229" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8eea80d-b50f-4bad-9f8f-3d5d0b24d229">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 56c4947f88a7e300458b4682.jpg to 56c4947f88a7e300458b4682.jpg
# User uploaded file "56c4947f88a7e300458b4682.jpg" with length 37347 bytes

# %%
# ori
im = Image.open(fn)
_ = np.asarray(im)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=341x447 at 0x7FD028F8AED0>

# %%
# grayscale
im = Image.open(fn).convert("L")
_ = np.asarray(im)
im
# Out:
# <PIL.Image.Image image mode=L size=341x447 at 0x7FD028F2C1D0>

# %%
# first 10 pixels value
print(a[0][0:10])
# height, width
print(a.shape)
# Out:
# [235 235 235 235 235 235 235 235 237 236]
# (447, 341)
